# %%
"""
Acoustic Full Waveform Inversion using Salvus
==============================================
2-D acoustic FWI on a unit square domain [0,1]^2.

Workflow:
  1. Build homogeneous starting mesh and layered true mesh.
  2. Define source-receiver geometry and simulation configuration.
  3. Run forward simulation on the true model to generate observed data.
  4. Configure L2 misfit and inversion problem.
  5. Iterate the inversion loop.
"""

# ============================================================
# Imports
# ============================================================
import sys
import importlib
from pathlib import Path
from datetime import datetime

import numpy as np
import salvus
import salvus.namespace as sn
import salvus.mesh.layered_meshing as lm

path_to_add = str(Path.cwd() / "tomography")
if path_to_add not in sys.path:
    sys.path.append(path_to_add)

import my_code.utilities
importlib.reload(my_code.utilities)
from my_code.utilities import *


# ============================================================
# Configuration
# ============================================================
tx = 1

SITE_NAME = "isambard_oliver"
RANKS     = 8

f_c  = 2e4
VP   = 5000.0
RHO  = 2600.0

x0, x1 = 0.0, 1.0
y0, y1 = 0.0, 1.0

PROJECT_DIR = '/home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project'
DATA_DIR    = '/home/b6as/oliverwfy.b6as/workspace/acoustic_model/data'
IMAGE_DIR   = '/home/b6as/oliverwfy.b6as/workspace/acoustic_model/image'

for d in [PROJECT_DIR, DATA_DIR, IMAGE_DIR]:
    Path(d).mkdir(parents=True, exist_ok=True)


# ============================================================
# Project
# ============================================================

PROJECT_NAME = 'acoustic_forward_5paris_' + str(tx) + 'tx_salvus'
domain = sn.domain.dim2.BoxDomain(x0=x0, x1=x1, y0=y0, y1=y1)

p = sn.Project.from_domain(
    path=Path(PROJECT_DIR, PROJECT_NAME), domain=domain, load_if_exists=True
)


# ============================================================
# Mesh construction
# ============================================================

reference_frequency     = f_c * 2
elements_per_wavelength = 3
model_order             = 4
number_of_wavelengths   = 2
free_surfaces           = ['y0', 'y1']

ab_params = salvus.mesh.simple_mesh.basic_mesh.AbsorbingBoundaryParameters(
    free_surface=free_surfaces,
    number_of_wavelengths=number_of_wavelengths,
    reference_velocity=VP,
    reference_frequency=reference_frequency,
)

mesh_res = sn.MeshResolution(
    reference_frequency=reference_frequency,
    elements_per_wavelength=elements_per_wavelength,
    model_order=model_order,
)

# Homogeneous starting model
m_homo    = sn.material.from_params(rho=RHO, vp=VP)
mesh_homo = lm.mesh_from_domain(
    domain=domain,
    model=sn.layered_meshing.MeshingProtocol(m_homo, ab=ab_params),
    mesh_resolution=mesh_res,
)

# True model: layer with VP *= 1.5 between y = 0.4 and y = 0.6
mesh_true   = mesh_homo.copy()
centroids   = mesh_true.get_element_centroid()
defect_mask = (centroids[:, 1] >= 0.4) & (centroids[:, 1] <= 0.6)
mesh_true.elemental_fields["VP"][defect_mask] = 1.5 * VP

# Region of interest for inversion
roi      = [(0.0, 1.0), (0.4, 0.6)]
mesh_roi = generate_mesh_roi(mesh_homo, roi)


# ============================================================
# Source-receiver geometry
# ============================================================

amplitude_ratio = 1e3

s_loc = [(x, 0.3) for x in np.linspace(0.2, 0.8, tx)]
r_loc = [(x, 0.7) for x in np.linspace(0.2, 0.8, tx)]

sources = [
    sn.simple_config.source.cartesian.ScalarPoint2D(x=s[0], y=s[1], f=amplitude_ratio)
    for s in s_loc
]

receivers = [
    sn.simple_config.receiver.cartesian.Point2D(
        x=r[0], y=r[1], station_code=f"R{j+1}", fields=["phi"]
    )
    for j, r in enumerate(r_loc)
]

event_ls = [
    sn.Event(event_name=f"event_{i+1}", sources=sources[i], receivers=receivers)
    for i in range(len(sources))
]

p.add_to_project(event_ls)


# ============================================================
# Simulation configuration
# ============================================================

end_time               = 2e-4
start_time             = 0.0
sampling_rate_in_hertz = f_c * 200
time_shift_in_seconds  = 1.0 / f_c

wavelet = sn.simple_config.stf.Ricker(
    center_frequency=f_c,
    time_shift_in_seconds=time_shift_in_seconds,
)

waveform_config = sn.WaveformSimulationConfiguration(
    start_time_in_seconds=start_time,
    end_time_in_seconds=end_time,
    time_step_in_seconds=1.0 / sampling_rate_in_hertz,
)

event_config = sn.EventConfiguration(
    wavelet=wavelet,
    waveform_simulation_configuration=waveform_config,
)

homo_model = 'forward_simulation_homogeneous_model'
true_model = 'forward_simulation_layered_model'

p.add_to_project(
    sn.UnstructuredMeshSimulationConfiguration(
        unstructured_mesh=mesh_homo,
        name=homo_model,
        event_configuration=event_config,
    ),
    overwrite=True,
)
p.add_to_project(
    sn.UnstructuredMeshSimulationConfiguration(
        unstructured_mesh=mesh_true,
        name=true_model,
        event_configuration=event_config,
    ),
    overwrite=True,
)


# ============================================================
# Forward simulation — generate observed data from true model
# ============================================================

t0 = datetime.now()

forward_simulation(
    p,
    simulation_name=true_model,
    events=event_ls,
    fields=None,
    sampling_interval_in_time_steps=10,
    RANKS=RANKS,
)

print(f"Forward simulation completed in {datetime.now() - t0}")


# ============================================================
# Misfit configuration
# ============================================================

misfit_name = 'L2_misfit'

p += sn.MisfitConfiguration(
    name=misfit_name,
    observed_data=true_model,
    misfit_function="L2",
    receiver_field="phi",
)


# ============================================================
# Inverse problem configuration
# ============================================================

inverse_config_name = 'inversion_L2'

invconfig = sn.InverseProblemConfiguration(
    name=inverse_config_name,
    prior_model=homo_model,
    events=[e.event_name for e in event_ls],
    misfit_configuration=misfit_name,
    mapping=sn.Mapping(
        scaling="relative_deviation_from_prior",
        inversion_parameters=["VP"],
        region_of_interest=mesh_roi,
    ),
    method=sn.TrustRegion(initial_trust_region_linf=1.0),
    wavefield_compression=sn.WavefieldCompression(
        forward_wavefield_sampling_interval=10
    ),
    job_submission=sn.SiteConfig(site_name=SITE_NAME, ranks_per_job=RANKS),
)

add_inversion(p, invconfig)

p.inversions.set_job_submission_configuration(
    inverse_config_name, sn.SiteConfig(site_name=SITE_NAME, ranks_per_job=RANKS)
)


# ============================================================
# Inversion loop
# ============================================================

max_iterations           = 10
timeout_in_seconds       = 360
ping_interval_in_seconds = 50
delete_disposable_files  = "all"

for i in range(max_iterations):
    p.inversions.iterate(
        inverse_problem_configuration=inverse_config_name,
        timeout_in_seconds=timeout_in_seconds,
        ping_interval_in_seconds=ping_interval_in_seconds,
        delete_disposable_files=delete_disposable_files,
    )
# Out:
# Accordion()
# [2026-04-22 19:48:22,007] INFO: Submitting job array with 2 jobs ...
# Initializing Jobs and Uploading Files for Individual Jobs:   0%|          | 0/2 [00:00<?, ?job/s]
# VBox()
# Forward simulation completed in 0:00:23.741675
# [2026-04-22 19:48:45,236] INFO: Adding new iteration #0.
# [2026-04-22 19:48:45,274] INFO: Resuming iteration #0.
#
# [2026-04-22 19:48:45,277] INFO: 1 new tasks have been issued.
# [2026-04-22 19:48:45,277] INFO: Processing task `misfit_and_gradient`
# [2026-04-22 19:48:45,568] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:48:46,023] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:48:46,023] INFO: Some tasks of iteration #0 are still running. Please check again later.
# [2026-04-22 19:49:36,033] INFO: Processing task `misfit_and_gradient`
# [2026-04-22 19:49:38,919] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:49:39,369] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:49:39,370] INFO: Some tasks of iteration #0 are still running. Please check again later.
# [2026-04-22 19:50:29,384] INFO: Processing task `misfit_and_gradient`
# [2026-04-22 19:50:33,743] INFO:
# Iteration 0: Number of events: 2	 chi = 397037.25	 ||g|| = 8534148.453015802
# pred = ---	ared = ---	norm_update = ---	tr_radius = ---
# [2026-04-22 19:50:33,762] INFO: 1 new tasks have been issued.
# [2026-04-22 19:50:33,762] INFO: Processing task `misfit`
# [2026-04-22 19:50:33,990] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:50:34,452] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:50:34,452] INFO: Some tasks of iteration #0 are still running. Please check again later.
# [2026-04-22 19:51:24,516] INFO: Processing task `misfit`
# [2026-04-22 19:51:26,828] INFO:
# old misfit control group: 397037.25
# new misfit control group: 583615.78125
# predicted reduction control group: -905855.0625
# actual reduction control group: 186578.53125
# 0 out of 2 event(s) improved the misfit.
# [2026-04-22 19:51:26,828] INFO:
# Model update rejected.
# [2026-04-22 19:51:27,770] INFO: 1 new tasks have been issued.
# [2026-04-22 19:51:27,770] INFO: Processing task `misfit`
# [2026-04-22 19:51:28,027] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:51:28,468] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:51:28,469] INFO: Some tasks of iteration #0 are still running. Please check again later.
# [2026-04-22 19:52:18,533] INFO: Processing task `misfit`
# [2026-04-22 19:52:20,892] INFO:
# old misfit control group: 397037.25
# new misfit control group: 292063.125
# predicted reduction control group: -452927.53125
# actual reduction control group: -104974.125
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 19:52:20,892] INFO:
# Model update accepted.
# [2026-04-22 19:52:21,312] INFO: 1 new tasks have been issued.
# [2026-04-22 19:52:21,312] INFO: Processing task `finalize_iteration`
# [2026-04-22 19:52:21,450] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00000
# [2026-04-22 19:52:21,513] INFO: Freed up 0.0 bytes of space.
# [2026-04-22 19:52:21,514] INFO: Successfully completed iteration #0.
# [2026-04-22 19:52:21,520] INFO: Adding new iteration #1.
# [2026-04-22 19:52:21,559] INFO: Resuming iteration #1.
#
# [2026-04-22 19:52:21,562] INFO: 1 new tasks have been issued.
# [2026-04-22 19:52:21,562] INFO: Processing task `gradient`
# [2026-04-22 19:52:21,996] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:52:22,449] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:52:22,449] INFO: Some tasks of iteration #1 are still running. Please check again later.
# [2026-04-22 19:53:12,460] INFO: Processing task `gradient`
# [2026-04-22 19:53:16,595] INFO:
# Iteration 1: Number of events: 2	 chi = 292063.125	 ||g|| = 6823617.6060175
# pred = -452927.53125	ared = -104974.125	norm_update = 0.10614475637235224	tr_radius = 0.10614475637235224
# [2026-04-22 19:53:16,652] INFO: 1 new tasks have been issued.
# [2026-04-22 19:53:16,652] INFO: Processing task `misfit`
# [2026-04-22 19:53:16,880] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:53:17,326] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:53:17,327] INFO: Some tasks of iteration #1 are still running. Please check again later.
# [2026-04-22 19:54:07,372] INFO: Processing task `misfit`
# [2026-04-22 19:54:09,675] INFO:
# old misfit control group: 292063.125
# new misfit control group: 177181.6640625
# predicted reduction control group: -115072.109375
# actual reduction control group: -114881.4609375
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 19:54:09,675] INFO:
# Model update accepted.
# [2026-04-22 19:54:09,676] INFO: 1 new tasks have been issued.
# [2026-04-22 19:54:09,676] INFO: Processing task `finalize_iteration`
# [2026-04-22 19:54:09,787] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00001
# [2026-04-22 19:54:10,096] INFO: Freed up 2.4 MB of space.
# [2026-04-22 19:54:10,097] INFO: Successfully completed iteration #1.
# [2026-04-22 19:54:10,104] INFO: Adding new iteration #2.
# [2026-04-22 19:54:10,145] INFO: Resuming iteration #2.
#
# [2026-04-22 19:54:10,148] INFO: 1 new tasks have been issued.
# [2026-04-22 19:54:10,148] INFO: Processing task `gradient`
# [2026-04-22 19:54:10,607] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:54:11,171] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:54:11,171] INFO: Some tasks of iteration #2 are still running. Please check again later.
# [2026-04-22 19:55:01,186] INFO: Processing task `gradient`
# [2026-04-22 19:55:05,956] INFO:
# Iteration 2: Number of events: 2	 chi = 177181.6640625	 ||g|| = 2673248.7398698987
# pred = -115072.109375	ared = -114881.4609375	norm_update = 0.03389838812033878	tr_radius = 0.10614475637235224
# [2026-04-22 19:55:06,049] INFO: 1 new tasks have been issued.
# [2026-04-22 19:55:06,049] INFO: Processing task `misfit`
# [2026-04-22 19:55:06,311] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:55:07,068] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:55:07,069] INFO: Some tasks of iteration #2 are still running. Please check again later.
# [2026-04-22 19:55:57,147] INFO: Processing task `misfit`
# [2026-04-22 19:55:59,410] INFO:
# old misfit control group: 177181.6640625
# new misfit control group: 139764.4453125
# predicted reduction control group: -23239.638671875
# actual reduction control group: -37417.21875
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 19:55:59,411] INFO:
# Model update accepted.
# [2026-04-22 19:55:59,411] INFO: 1 new tasks have been issued.
# [2026-04-22 19:55:59,411] INFO: Processing task `finalize_iteration`
# [2026-04-22 19:55:59,580] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00002
# [2026-04-22 19:55:59,973] INFO: Freed up 2.4 MB of space.
# [2026-04-22 19:55:59,974] INFO: Successfully completed iteration #2.
# [2026-04-22 19:55:59,981] INFO: Adding new iteration #3.
# [2026-04-22 19:56:00,028] INFO: Resuming iteration #3.
#
# [2026-04-22 19:56:00,032] INFO: 1 new tasks have been issued.
# [2026-04-22 19:56:00,033] INFO: Processing task `gradient`
# [2026-04-22 19:56:00,485] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:56:00,931] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:56:00,932] INFO: Some tasks of iteration #3 are still running. Please check again later.
# [2026-04-22 19:56:50,942] INFO: Processing task `gradient`
# [2026-04-22 19:56:55,313] INFO:
# Iteration 3: Number of events: 2	 chi = 139764.4453125	 ||g|| = 2032544.5619912003
# pred = -23239.638671875	ared = -37417.21875	norm_update = 0.018783950491910808	tr_radius = 0.06779677624067756
# [2026-04-22 19:56:55,451] INFO: 1 new tasks have been issued.
# [2026-04-22 19:56:55,452] INFO: Processing task `misfit`
# [2026-04-22 19:56:55,670] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:56:56,543] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:56:56,544] INFO: Some tasks of iteration #3 are still running. Please check again later.
# [2026-04-22 19:57:46,618] INFO: Processing task `misfit`
# [2026-04-22 19:57:49,190] INFO:
# old misfit control group: 139764.4453125
# new misfit control group: 96739.46875
# predicted reduction control group: -35662.6953125
# actual reduction control group: -43024.9765625
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 19:57:49,190] INFO:
# Model update accepted.
# [2026-04-22 19:57:49,190] INFO: 1 new tasks have been issued.
# [2026-04-22 19:57:49,191] INFO: Processing task `finalize_iteration`
# [2026-04-22 19:57:49,302] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00003
# [2026-04-22 19:57:49,641] INFO: Freed up 2.4 MB of space.
# [2026-04-22 19:57:49,642] INFO: Successfully completed iteration #3.
# [2026-04-22 19:57:49,650] INFO: Adding new iteration #4.
# [2026-04-22 19:57:49,694] INFO: Resuming iteration #4.
#
# [2026-04-22 19:57:49,696] INFO: 1 new tasks have been issued.
# [2026-04-22 19:57:49,696] INFO: Processing task `gradient`
# [2026-04-22 19:57:50,107] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:57:50,554] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:57:50,554] INFO: Some tasks of iteration #4 are still running. Please check again later.
# [2026-04-22 19:58:40,566] INFO: Processing task `gradient`
# [2026-04-22 19:58:44,751] INFO:
# Iteration 4: Number of events: 2	 chi = 96739.46875	 ||g|| = 1130217.8208469374
# pred = -35662.6953125	ared = -43024.9765625	norm_update = 0.0375679040826191	tr_radius = 0.037567900983821616
# [2026-04-22 19:58:44,918] INFO: 1 new tasks have been issued.
# [2026-04-22 19:58:44,918] INFO: Processing task `misfit`
# [2026-04-22 19:58:45,140] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:58:45,576] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:58:45,577] INFO: Some tasks of iteration #4 are still running. Please check again later.
# [2026-04-22 19:59:35,621] INFO: Processing task `misfit`
# [2026-04-22 19:59:38,226] INFO:
# old misfit control group: 96739.46875
# new misfit control group: 105909.20703125
# predicted reduction control group: -14812.72265625
# actual reduction control group: 9169.73828125
# 0 out of 2 event(s) improved the misfit.
# [2026-04-22 19:59:38,227] INFO:
# Model update rejected.
# [2026-04-22 19:59:39,214] INFO: 1 new tasks have been issued.
# [2026-04-22 19:59:39,215] INFO: Processing task `misfit`
# [2026-04-22 19:59:39,439] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 19:59:39,901] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 19:59:39,902] INFO: Some tasks of iteration #4 are still running. Please check again later.
# [2026-04-22 20:00:29,973] INFO: Processing task `misfit`
# [2026-04-22 20:00:32,290] INFO:
# old misfit control group: 96739.46875
# new misfit control group: 91730.03125
# predicted reduction control group: -7406.361328125
# actual reduction control group: -5009.4375
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 20:00:32,290] INFO:
# Model update accepted.
# [2026-04-22 20:00:32,690] INFO: 1 new tasks have been issued.
# [2026-04-22 20:00:32,690] INFO: Processing task `finalize_iteration`
# [2026-04-22 20:00:32,834] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00004
# [2026-04-22 20:00:33,135] INFO: Freed up 2.4 MB of space.
# [2026-04-22 20:00:33,135] INFO: Successfully completed iteration #4.
# [2026-04-22 20:00:33,142] INFO: Adding new iteration #5.
# [2026-04-22 20:00:33,184] INFO: Resuming iteration #5.
#
# [2026-04-22 20:00:33,187] INFO: 1 new tasks have been issued.
# [2026-04-22 20:00:33,187] INFO: Processing task `gradient`
# [2026-04-22 20:00:33,612] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 20:00:34,044] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 20:00:34,045] INFO: Some tasks of iteration #5 are still running. Please check again later.
# [2026-04-22 20:01:24,058] INFO: Processing task `gradient`
# [2026-04-22 20:01:28,383] INFO:
# Iteration 5: Number of events: 2	 chi = 91730.03125	 ||g|| = 3033585.2664621114
# pred = -7406.361328125	ared = -5009.4375	norm_update = 0.014619531522721906	tr_radius = 0.014619531522721906
# [2026-04-22 20:01:28,589] INFO: 1 new tasks have been issued.
# [2026-04-22 20:01:28,589] INFO: Processing task `misfit`
# [2026-04-22 20:01:28,813] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 20:01:29,277] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 20:01:29,278] INFO: Some tasks of iteration #5 are still running. Please check again later.
# [2026-04-22 20:02:19,324] INFO: Processing task `misfit`
# [2026-04-22 20:02:21,587] INFO:
# old misfit control group: 91730.03125
# new misfit control group: 84964.7265625
# predicted reduction control group: -5285.33984375
# actual reduction control group: -6765.3046875
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 20:02:21,588] INFO:
# Model update accepted.
# [2026-04-22 20:02:21,588] INFO: 1 new tasks have been issued.
# [2026-04-22 20:02:21,588] INFO: Processing task `finalize_iteration`
# [2026-04-22 20:02:21,700] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00005
# [2026-04-22 20:02:22,024] INFO: Freed up 2.4 MB of space.
# [2026-04-22 20:02:22,024] INFO: Successfully completed iteration #5.
# [2026-04-22 20:02:22,035] INFO: Adding new iteration #6.
# [2026-04-22 20:02:22,093] INFO: Resuming iteration #6.
#
# [2026-04-22 20:02:22,096] INFO: 1 new tasks have been issued.
# [2026-04-22 20:02:22,096] INFO: Processing task `gradient`
# [2026-04-22 20:02:22,566] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 20:02:23,014] INFO: Launched adjoint simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 20:02:23,014] INFO: Some tasks of iteration #6 are still running. Please check again later.
# [2026-04-22 20:03:13,027] INFO: Processing task `gradient`
# [2026-04-22 20:03:17,295] INFO:
# Iteration 6: Number of events: 2	 chi = 84964.7265625	 ||g|| = 1162655.333718467
# pred = -5285.33984375	ared = -6765.3046875	norm_update = 0.004886445541638445	tr_radius = 0.02923906304544381
# [2026-04-22 20:03:17,551] INFO: 1 new tasks have been issued.
# [2026-04-22 20:03:17,551] INFO: Processing task `misfit`
# [2026-04-22 20:03:17,771] INFO: Submitting job array with 2 jobs ...
#
# [2026-04-22 20:03:18,244] INFO: Launched simulations for 2 events. Please check again to see if they are finished.
# [2026-04-22 20:03:18,244] INFO: Some tasks of iteration #6 are still running. Please check again later.
# [2026-04-22 20:04:08,294] INFO: Processing task `misfit`
# [2026-04-22 20:04:10,564] INFO:
# old misfit control group: 84964.7265625
# new misfit control group: 77754.1953125
# predicted reduction control group: -4428.1806640625
# actual reduction control group: -7210.53125
# 2 out of 2 event(s) improved the misfit.
# [2026-04-22 20:04:10,564] INFO:
# Model update accepted.
# [2026-04-22 20:04:10,564] INFO: 1 new tasks have been issued.
# [2026-04-22 20:04:10,564] INFO: Processing task `finalize_iteration`
# [2026-04-22 20:04:10,679] INFO: ... searching for obsolete files in /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_2tx_salvus/INVERSIONS/inversion_L2/00006
# [2026-04-22 20:04:10,966] INFO: Freed up 2.4 MB of space.
# [2026-04-22 20:04:10,966] INFO: Successfully completed iteration #6.
# [2026-04-22 20:04:10,974] INFO: Adding new iteration #7.
# [2026-04-22 20:04:11,021] INFO: Resuming iteration #7.
#
# [2026-04-22 20:04:11,023] INFO: 1 new tasks have been issued.
# [2026-04-22 20:04:11,024] INFO: Processing task `gradient`
# [2026-04-22 20:04:11,468] INFO: Submitting job array with 2 jobs ...

# %%
import numpy as np
tx=1

s_loc = [(x, 0.3) for x in np.linspace(0.2, 0.8, tx)]
# Out:
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# [2026-04-16 13:42:22,004] INFO: Loading project from /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_salvus.
# VBox(children=(HTML(value='\n            <p><i>This is only a preview. Use ParaView to actually investigate\n …

# %%
# salvus project 
p_salvus = sn.Project.from_domain(
    path=Path(PROJECT_DIR, 'acoustic_forward_5paris_5tx_salvus'), domain=domain, load_if_exists=True
)
p_salvus.inversions.get_model("inversion_L2", 9)
# Out:
# Accordion(children=(HTML(value='\n                <head>\n                <style>\n                td {\n     …
# [2026-04-16 13:43:29,182] INFO: Loading project from /home/b6as/oliverwfy.b6as/workspace/acoustic_model/Project/acoustic_forward_5paris_5tx_salvus.
# VBox(children=(HTML(value='\n            <p><i>This is only a preview. Use ParaView to actually investigate\n …
